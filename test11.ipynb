# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/patshists/pytorch/123/4/utils/metrics.py
# /kaggle/input/patshists/pytorch/123/4/utils/losses.py
# /kaggle/input/patshists/pytorch/123/4/utils/tools.py
# /kaggle/input/patshists/pytorch/123/4/utils/masking.py
# /kaggle/input/patshists/pytorch/123/4/utils/timefeatures.py
# /kaggle/input/patshists/pytorch/123/4/utils/__init__.py
# /kaggle/input/patshists/pytorch/123/4/utils/build_model.py
# /kaggle/input/patshists/pytorch/123/4/utils/logger.py
# /kaggle/input/patshists/pytorch/123/4/utils/data/cifar-10-batches-py/data_batch_1
# /kaggle/input/patshists/pytorch/123/4/utils/data/cifar-10-batches-py/data_batch_2
# /kaggle/input/patshists/pytorch/123/4/utils/data/cifar-10-batches-py/batches.meta
# /kaggle/input/patshists/pytorch/123/4/utils/data/cifar-10-batches-py/test_batch
# /kaggle/input/patshists/pytorch/123/4/utils/data/cifar-10-batches-py/data_batch_3
# /kaggle/input/patshists/pytorch/123/4/utils/data/cifar-10-batches-py/data_batch_5
# ...

# %%
pip install breizhcrops
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cd /kaggle/input/patshists/pytorch/123/4/examples
# Out:
# /kaggle/input/patshists/pytorch/123/4/examples

# %%
pip install einops
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 2.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python /kaggle/input/patshists/pytorch/123/4/examples/train.py patchsits --learning_rate 0.01 --weight_decay 5e-08 --preload-ram
# Out:
# Setting up datasets in /kaggle/working/data, level L1C
# classmapping.csv: 8.19kB [00:00, 12.3kB/s]
# frh01.csv: 13.9MB [00:02, 5.87MB/s]
# downloading /kaggle/working/data/2017/L1C/frh01.h5.tar.gz
# frh01.h5.tar.gz: 1.64GB [01:18, 20.9MB/s]
# extracting /kaggle/working/data/2017/L1C/frh01.h5.tar.gz to /kaggle/working/data/2017/L1C/frh01.h5
# removing /kaggle/working/data/2017/L1C/frh01.h5.tar.gz
# checking integrity by file size...
# ok!
# codes.csv: 24.6kB [00:00, 37.8kB/s]
# loading data into RAM: 100%|██████████| 178613/178613 [01:06<00:00, 2672.06it/s]
# frh02.csv: 11.2MB [00:02, 5.18MB/s]
# downloading /kaggle/working/data/2017/L1C/frh02.h5.tar.gz
# frh02.h5.tar.gz: 1.45GB [01:02, 23.2MB/s]
# extracting /kaggle/working/data/2017/L1C/frh02.h5.tar.gz to /kaggle/working/data/2017/L1C/frh02.h5
# removing /kaggle/working/data/2017/L1C/frh02.h5.tar.gz
# checking integrity by file size...
# ok!
# loading data into RAM: 100%|██████████| 140645/140645 [00:53<00:00, 2614.84it/s]
# ...

# %%
# !rm -rf /kaggle/working/
# Out:
# rm: cannot remove '/kaggle/working/': Device or resource busy

# %%
# !python /kaggle/input/train-py/train.py patchtst --learning-rate 0.001 --weight-decay 5e-08 --preload-ram
# Out:
# python: can't open file '/kaggle/input/train-py/train.py': [Errno 2] No such file or directory
